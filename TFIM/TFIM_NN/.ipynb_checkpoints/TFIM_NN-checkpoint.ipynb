# %%
import numpy as np
import pickle
from tqdm import tqdm
from scipy.sparse import csr_matrix, kron, eye
import scipy.sparse.linalg as las
import scipy.linalg as la
import matplotlib.pyplot as plt
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Input
from keras import optimizers
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
font = {'size'   : 18}
plt.rc('font', **font)

# %%
I = csr_matrix(np.array([[1, 0], 
                         [0, 1]]))
X = csr_matrix(np.array([[0, 1], 
                         [1, 0]]))
Y = csr_matrix(np.array([[0, -1j], 
                         [1j, 0]]))
Z = csr_matrix(np.array([[1, 0], 
                         [0, -1]]))

# %%
# number of spins
L  = 20
# number of steps in the grid of transverse field values
D  = 21
# grid of transverse field values
ta = np.linspace(0.01,2,D)
# number of configurations to be sampled for every longitudinal field in the grid
N  = 10000

# %%
# this function returns a quantum many-body Hamiltonian of the transverse field Ising model
def Ham(L=3, ta = 0.):
    if L == 2:
        return - kron(Z,Z) - ta * ( kron(X,I) + kron(I,X) )
    else:
        Lm1 = eye(2**(L-1))
        Lm2 = eye(2**(L-2))
        return kron(Ham(L-1,ta),I) - kron(Lm2,kron(Z,Z)) - ta * kron(Lm1,X)

# %%
# this guy makes samples' array of size (D,N),
# i.e., N  bitstrings for D=len(ta) longitudinal field values
def make_samples(N,L,ta):
    
    samples = np.zeros((len(ta),N))
    
    for i in range(len(ta)):
        samples[i] = np.random.choice(2**L, N, p=las.eigsh(Ham(L,ta[i]), k=1000)[1][:,0]**2)
    
    string_samples = [['' for i in range(N)] for j in range(len(ta))]
    for i in range(len(ta)):
        for j in range(N):
            string_samples[i][j] = bin(int(samples[i][j]))[2:].zfill(L)
    
    return string_samples

# %%
# here we preprocess the data to feed to the NN, i.e. take two transverse fields' indeces (k and m)
# and label target data as follows: ta[k] -> 0, ta[m] -> 1
# here "samples" array should be an array of (D,N) size
def data_for_MLP(k,m,samples):
    
    x = np.zeros((int(2*N),L))
    for i in range(int(N)):
        x[i] = [int(a) for a in [*samples[k][i]]]
    for i in range(int(N)):
        x[i+int(N)] = [int(a) for a in [*samples[m][i]]]
    
    y = np.zeros((int(2*N), 1))
    for i in range(int(N)):
        y[i] = 0
    for i in range(int(N),int(2*N)):
        y[i] = 1
    
    return x,y

# %%
# load prepared samples
samples = np.load('20_spins_samples_Ising.npy', allow_pickle=True)

# %%
# define the model, which is a simple feed-forward NN without hidden layers
def train_model(data_for_MLP, batch_size, epochs):
    model = Sequential()
    model.add(Dense(L, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
    history = model.fit(data_for_MLP[0], data_for_MLP[1], validation_split=0.2, epochs=epochs, batch_size=batch_size, verbose=0)
    return model

# %%
# %%time
# let's now train D-1 models, each will distinguish samples from H(ta[0]) and H(ta[i])
models = []
for i in tqdm(range(D-1)):
    models.append(train_model(data_for_MLP(0,i+1,samples), 32, 100))
# Out:
# 100%|██████████| 20/20 [16:18<00:00, 48.95s/it]
# CPU times: user 18min 33s, sys: 1min 6s, total: 19min 39s
# Wall time: 16min 18s

# %%
# let's now save the models
with open('Models_for_TFIM/models_for_TFIM.pkl', 'wb') as f:
    pickle.dump(models, f)

# %%
# let's now load the saved list of models
with open('Models_for_TFIM/models_for_TFIM.pkl', 'rb') as f:
    models = pickle.load(f)

# %%
# %%time
# let's now look at each model's prediction for the corresponding samples
predicts = np.zeros(D-1)
for i in tqdm(range(D-1)):
    predicts[i] = np.mean(models[i].predict(data_for_MLP(0,i+1,samples)[0][int(N):]))
# Out:
# 100%|██████████| 20/20 [00:05<00:00,  3.87it/s]
# CPU times: user 5.44 s, sys: 260 ms, total: 5.7 s
# Wall time: 5.17 s

# %%
# let us now look how the curve would look if we average it for many runs
k=40
predicts_averaging = np.zeros((k, D-1))
for j in tqdm(range(k)):
    
    models=[]
    for i in range(D-1):
        models.append(train_model(data_for_MLP(0,i+1,samples), 32, 100))
        
    with open('Models_for_TFIM/models_for_TFIM'+str(j)+'.pkl', 'wb') as f:
        pickle.dump(models, f)
    
    for i in range(D-1):
        predicts_averaging[j][i] = np.mean(models[i].predict(data_for_MLP(0,i+1,samples)[0][int(N):]))
# Out:
# 100%|██████████| 40/40 [11:28:58<00:00, 1033.45s/it]

# %%
np.save('predicts_averaging.npy', predicts_averaging)

# %%
for i in range(k):
    plt.plot(predicts_averaging[i])

# %%
predicts_mean = np.mean(predicts_averaging, axis=0)
predicts_var  = np.std(predicts_averaging, axis=0)

# %%
plt.errorbar(ta[1:],
             predicts_mean,
             yerr=predicts_var)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.figure(figsize=(9,4.5))
plt.fill_between(ta[1:],
                predicts_mean-predicts_var, 
                predicts_mean+predicts_var, color='blue')
plt.plot(ta[1:], predicts_mean, c='black')
plt.xlabel('$τ$', labelpad=10)
plt.text(0.45, 0.8, 'Phase 1', fontsize=16)
plt.text(1.25, 0.8, 'Phase 2', fontsize=16)
plt.ylabel('$P(τ)$',rotation=0, labelpad=10)
plt.legend(['NN output'], fontsize=18)
plt.xlim((0.25,1.75))
plt.ylim((0.3,1.05))
plt.vlines(1,0,2, linestyles='dashed')
plt.tight_layout()
plt.savefig('TFIM_NN_Output.pdf',transparent=True)
plt.show()

# %%
plt.figure(figsize=(9,4.5))
plt.fill_between(ta[1:],
                predicts_mean-predicts_var, 
                predicts_mean+predicts_var, color='blue')
plt.plot(ta[1:], predicts_mean, c='black')
plt.xlabel('$τ$', labelpad=10)
plt.text(0.45, 0.8, 'Phase 1', fontsize=16)
plt.text(1.25, 0.8, 'Phase 2', fontsize=16)
plt.ylabel('$P(τ)$',rotation=0, labelpad=10)
plt.legend(['NN output'], fontsize=18)
plt.xlim((0.25,1.75))
plt.ylim((0.3,1.05))
plt.vlines(1,0,2, linestyles='dashed')
plt.tight_layout()
#plt.savefig('TFIM_NN_Output.pdf',transparent=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 4.5))
im = ax.imshow(np.load('weights.npy'))
ax.set_xticks([i for i in np.arange(0,40,5)])
ax.set_xticklabels([np.round(i,1) for i in np.linspace(0,2,9)])
ax.set_yticks([])
cbar = ax.figure.colorbar(im, ax=ax, shrink=0.75, aspect=5)
plt.xlabel('$τ$',labelpad=10)
plt.ylabel('Spins', labelpad=10)
fig.tight_layout()
plt.savefig('TFIM_NN_Weights.pdf', transparent=True)
